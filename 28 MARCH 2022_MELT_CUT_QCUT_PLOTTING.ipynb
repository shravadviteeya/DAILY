# %%
# pands cut, melt and plotting functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ############################# CUT AND QCUT#############################

# %%
df = pd.read_csv("G:\\My Drive\\Data\\iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ######################### CUT ##################

# %%
df["Sepal"] = pd.cut(df.SepalLengthCm, [0,6,7,10], labels = ["s","m","l"])

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species Sepal
# 0       Iris-setosa     s
# 1       Iris-setosa     s
# 2       Iris-setosa     s
# 3       Iris-setosa     s
# ...

# %%
from matplotlib import colors
import numpy as np
color=list(colors.ColorConverter.colors.keys())[0:3]
x=0
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
for i in df.Species.unique():
    df[df.Species==i].plot(kind="scatter",x="Sepal",y="SepalLengthCm",label=i,c=color[x],ax=ax)
    x=x+1
    plt.figure()

# %%
pd.qcut(df.SepalLengthCm,4)
# Out:
# 0      (4.2989999999999995, 5.1]
# 1      (4.2989999999999995, 5.1]
# 2      (4.2989999999999995, 5.1]
# 3      (4.2989999999999995, 5.1]
# 4      (4.2989999999999995, 5.1]
#                  ...
# 145                   (6.4, 7.9]
# 146                   (5.8, 6.4]
# 147                   (6.4, 7.9]
# 148                   (5.8, 6.4]
# 149                   (5.8, 6.4]
# Name: SepalLengthCm, Length: 150, dtype: category
# Categories (4, interval[float64]): [(4.2989999999999995, 5.1] < (5.1, 5.8] < (5.8, 6.4] < (6.4, 7.9]]

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species', 'Sepal'],
#       dtype='object')

# %%
from matplotlib import colors
import numpy as np 

color = list(colors.ColorConvertor.colors.keys())[0:3]
x = 0
fig = plt.figure()
ax = fig.add

# %%
### cut 

# from the variables cut the value

# %%
bins=pd.IntervalIndex.from_tuples([(0,5),(5,6),(6,8)])
df["Sepal"]=pd.cut(df.SepalLengthCm,bins=bins)
l=["small","medium","large"]
for i,x in zip(df.Sepal.unique(),l):
    print (i,x)
# Out:
# (5, 6] small
# (0, 5] medium
# (6, 8] large

# %%
df.Sepal
# Out:
# 0      (0.0, 6.5]
# 1      (0.0, 6.5]
# 2      (0.0, 6.5]
# 3      (0.0, 6.5]
# 4      (0.0, 6.5]
#           ...
# 145    (6.6, 7.0]
# 146    (0.0, 6.5]
# 147    (0.0, 6.5]
# 148    (0.0, 6.5]
# 149    (0.0, 6.5]
# Name: Sepal, Length: 150, dtype: category
# Categories (3, interval[float64]): [(0.0, 6.5] < (6.6, 7.0] < (7.0, 10.0]]

# %% [markdown]
# ############### MELT FUNCTION ############################
# # SIMILAR TO PIVOT TABLES MELT FUNCTION IS USED TO PIVOT DATA
# # IF YOU HAVE LARGE DATA YOU CAN EASILY FILTER THE DATA WITH THE HELP OF MELT FUNCTION

# %%
df1 = pd.read_csv("G:\\My Drive\\Data\\iris.csv")
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
DF2 = pd.melt(df1, id_vars= ("Id","Species"))
DF2
# id_vars : that columns that you want to entact
# Out:
#       Id         Species       variable  value
# 0      1     Iris-setosa  SepalLengthCm    5.1
# 1      2     Iris-setosa  SepalLengthCm    4.9
# 2      3     Iris-setosa  SepalLengthCm    4.7
# 3      4     Iris-setosa  SepalLengthCm    4.6
# 4      5     Iris-setosa  SepalLengthCm    5.0
# ..   ...             ...            ...    ...
# 595  146  Iris-virginica   PetalWidthCm    2.3
# 596  147  Iris-virginica   PetalWidthCm    1.9
# 597  148  Iris-virginica   PetalWidthCm    2.0
# 598  149  Iris-virginica   PetalWidthCm    2.3
# 599  150  Iris-virginica   PetalWidthCm    1.8
#
# [600 rows x 4 columns]

# %%
DF2[DF2["Species"] == "Iris-setosa"]
# Out:
#      Id      Species       variable  value
# 0     1  Iris-setosa  SepalLengthCm    5.1
# 1     2  Iris-setosa  SepalLengthCm    4.9
# 2     3  Iris-setosa  SepalLengthCm    4.7
# 3     4  Iris-setosa  SepalLengthCm    4.6
# 4     5  Iris-setosa  SepalLengthCm    5.0
# ..   ..          ...            ...    ...
# 495  46  Iris-setosa   PetalWidthCm    0.3
# 496  47  Iris-setosa   PetalWidthCm    0.2
# 497  48  Iris-setosa   PetalWidthCm    0.2
# 498  49  Iris-setosa   PetalWidthCm    0.2
# 499  50  Iris-setosa   PetalWidthCm    0.2
#
# [200 rows x 4 columns]

# %%
DF3 = pd.melt(df1, id_vars= ("Id","Species"), value_vars=("SepalLengthCm","SepalWidthCm"),var_name= "SepalCharacteristics" , value_name= "IN_CM" )
DF3
# id_vars : that columns that you want to entact
# value_vars : value columns that you want to merge into one value columns
# Out:
#       Id         Species SepalCharacteristics  IN_CM
# 0      1     Iris-setosa        SepalLengthCm    5.1
# 1      2     Iris-setosa        SepalLengthCm    4.9
# 2      3     Iris-setosa        SepalLengthCm    4.7
# 3      4     Iris-setosa        SepalLengthCm    4.6
# 4      5     Iris-setosa        SepalLengthCm    5.0
# ..   ...             ...                  ...    ...
# 295  146  Iris-virginica         SepalWidthCm    3.0
# 296  147  Iris-virginica         SepalWidthCm    2.5
# 297  148  Iris-virginica         SepalWidthCm    3.0
# 298  149  Iris-virginica         SepalWidthCm    3.4
# 299  150  Iris-virginica         SepalWidthCm    3.0
#
# [300 rows x 4 columns]

# %%
df2 = pd.DataFrame({ "A": {1:"a",2:"b",3:"c"},
                     "B": {1:1,2:2,3:3},
                     "C": {1:2,2:4,3:6}})
df2
# Out:
#    A  B  C
# 1  a  1  2
# 2  b  2  4
# 3  c  3  6

# %%
pd.melt(df2,id_vars= ("A"))
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      2
# 2  c        B      3
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %%
pd.melt(df2,id_vars= ("A") , value_vars= ("B","C"), var_name= "X")
# Out:
#    A  X  value
# 0  a  B      1
# 1  b  B      2
# 2  c  B      3
# 3  a  C      2
# 4  b  C      4
# 5  c  C      6

# %%
pd.melt(df2,id_vars= ("A") , value_vars= ("B","C"), var_name= "X" , value_name="Y")
# Out:
#    A  X  Y
# 0  a  B  1
# 1  b  B  2
# 2  c  B  3
# 3  a  C  2
# 4  b  C  4
# 5  c  C  6

# %% [markdown]
# ############### CUT and QCUT FUNCTION ############################
# CUT FUNCTION DIVIDES THE VALUES IN SPECIFIC RANGE
# DATA BINNING: NO OF BINS IN WHICH DATA TO BE PARTITIONED
# Bin labels must be one fewer than the number of bin edges

# %%
df3 = pd.read_csv("G:\\My Drive\\Data\\StudentsPerformance.csv")
df3
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df3.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df4 = df3.drop(columns= ['race/ethnicity', 'parental level of education', 'lunch',
       'test preparation course'])

# %%
df4.head()
# Out:
#    gender  math score  reading score  writing score
# 0  female          72             72             74
# 1  female          69             90             88
# 2  female          90             95             93
# 3    male          47             57             44
# 4    male          76             78             75

# %%
pd.cut(df4["math score"], bins = 4)
# Out:
# 0       (50.0, 75.0]
# 1       (50.0, 75.0]
# 2      (75.0, 100.0]
# 3       (25.0, 50.0]
# 4      (75.0, 100.0]
#            ...
# 995    (75.0, 100.0]
# 996     (50.0, 75.0]
# 997     (50.0, 75.0]
# 998     (50.0, 75.0]
# 999    (75.0, 100.0]
# Name: math score, Length: 1000, dtype: category
# Categories (4, interval[float64]): [(-0.1, 25.0] < (25.0, 50.0] < (50.0, 75.0] < (75.0, 100.0]]

# %%
pd.cut(df4["math score"], bins = 4).value_counts()
# Out:
# (50.0, 75.0]     576
# (75.0, 100.0]    274
# (25.0, 50.0]     143
# (-0.1, 25.0]       7
# Name: math score, dtype: int64

# %%
pd.cut(df4["math score"], bins = 5)
# Out:
# 0       (60.0, 80.0]
# 1       (60.0, 80.0]
# 2      (80.0, 100.0]
# 3       (40.0, 60.0]
# 4       (60.0, 80.0]
#            ...
# 995    (80.0, 100.0]
# 996     (60.0, 80.0]
# 997     (40.0, 60.0]
# 998     (60.0, 80.0]
# 999     (60.0, 80.0]
# Name: math score, Length: 1000, dtype: category
# Categories (5, interval[float64]): [(-0.1, 20.0] < (20.0, 40.0] < (40.0, 60.0] < (60.0, 80.0] < (80.0, 100.0]]

# %%
pd.cut(df4["math score"], bins = 5).value_counts()
# Out:
# (60.0, 80.0]     485
# (40.0, 60.0]     289
# (80.0, 100.0]    176
# (20.0, 40.0]      46
# (-0.1, 20.0]       4
# Name: math score, dtype: int64

# %%
grades =  ['C','B-','B+','A']  # bin lables
cut_bins = [0,  20, 50, 80, 100   ]

# %%
df4["grades"] = pd.cut(df4["math score"], bins = cut_bins )
df4
# Out:
#      gender  math score  reading score  writing score     grades
# 0    female          72             72             74   (50, 80]
# 1    female          69             90             88   (50, 80]
# 2    female          90             95             93  (80, 100]
# 3      male          47             57             44   (20, 50]
# 4      male          76             78             75   (50, 80]
# ..      ...         ...            ...            ...        ...
# 995  female          88             99             95  (80, 100]
# 996    male          62             55             55   (50, 80]
# 997  female          59             71             65   (50, 80]
# 998  female          68             78             77   (50, 80]
# 999  female          77             86             86   (50, 80]
#
# [1000 rows x 5 columns]

# %%
df4["grades"] = pd.cut(df4["math score"], bins = cut_bins , labels= grades)
df4
# Out:
#      gender  math score  reading score  writing score grades
# 0    female          72             72             74     B+
# 1    female          69             90             88     B+
# 2    female          90             95             93      A
# 3      male          47             57             44     B-
# 4      male          76             78             75     B+
# ..      ...         ...            ...            ...    ...
# 995  female          88             99             95      A
# 996    male          62             55             55     B+
# 997  female          59             71             65     B+
# 998  female          68             78             77     B+
# 999  female          77             86             86     B+
#
# [1000 rows x 5 columns]

# %%
############################# QCUT###############################
#(-0.001, 57.0]    266 here it excludes -0.001 and starts from 0 to 57 
#(66.0, 77.0]      264 here it excludes 66 and starts from 67 to 77 
#(57.0, 66.0]      241 here it excludes 57 and starts from 58 to 66
#(77.0, 100.0]     229 here it excludes 77 and starts from 78 to 100

# %%
pd.qcut(df4["math score"], q=4)
# Out:
# 0        (66.0, 77.0]
# 1        (66.0, 77.0]
# 2       (77.0, 100.0]
# 3      (-0.001, 57.0]
# 4        (66.0, 77.0]
#             ...
# 995     (77.0, 100.0]
# 996      (57.0, 66.0]
# 997      (57.0, 66.0]
# 998      (66.0, 77.0]
# 999      (66.0, 77.0]
# Name: math score, Length: 1000, dtype: category
# Categories (4, interval[float64]): [(-0.001, 57.0] < (57.0, 66.0] < (66.0, 77.0] < (77.0, 100.0]]

# %%
pd.qcut(df4["math score"], q=4).value_counts()
# Out:
# (-0.001, 57.0]    266
# (66.0, 77.0]      264
# (57.0, 66.0]      241
# (77.0, 100.0]     229
# Name: math score, dtype: int64

# %%
# q cut comes from the describe function

# %%
df4['math score'].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
pd.qcut(df4["math score"], q=6).value_counts()
# Out:
# (-0.001, 52.0]    179
# (66.0, 73.0]      173
# (60.0, 66.0]      168
# (73.0, 81.0]      166
# (52.0, 60.0]      160
# (81.0, 100.0]     154
# Name: math score, dtype: int64

# %%
df4["math_q_labels"] = pd.qcut(df4['math score'], q = [0,  .20, .50, .80, 1] , labels= grades)

# %%
df4
# Out:
#      gender  math score  reading score  writing score grades math_q_labels
# 0    female          72             72             74     B+            B+
# 1    female          69             90             88     B+            B+
# 2    female          90             95             93      A             A
# 3      male          47             57             44     B-             C
# 4      male          76             78             75     B+            B+
# ..      ...         ...            ...            ...    ...           ...
# 995  female          88             99             95      A             A
# 996    male          62             55             55     B+            B-
# 997  female          59             71             65     B+            B-
# 998  female          68             78             77     B+            B+
# 999  female          77             86             86     B+            B+
#
# [1000 rows x 6 columns]

# %%
df4["math_q_labels_false"] = pd.qcut(df4['math score'], q = [0,  .20, .50, .80, 1] , labels= False)
df4
# Out:
#      gender  math score  reading score  writing score grades math_q_labels  \
# 0    female          72             72             74     B+            B+
# 1    female          69             90             88     B+            B+
# 2    female          90             95             93      A             A
# 3      male          47             57             44     B-             C
# 4      male          76             78             75     B+            B+
# ..      ...         ...            ...            ...    ...           ...
# 995  female          88             99             95      A             A
# 996    male          62             55             55     B+            B-
# 997  female          59             71             65     B+            B-
# 998  female          68             78             77     B+            B+
# 999  female          77             86             86     B+            B+
#
#      math_q_labels_false
# 0                      2
# ...

# %%
#   q = [0,  .20, .50, .80, 1]   = math_q_labels_false [ 0 , 1 , 2 , 3 , 4]

# %%
# how to know the score

# %%
results , bin_edges = pd.qcut(df4['math score'], q = [0,  .20, .50, .80, 1] , labels= grades , retbins= True)

# %%
results
# Out:
# 0      B+
# 1      B+
# 2       A
# 3       C
# 4      B+
#        ..
# 995     A
# 996    B-
# 997    B-
# 998    B+
# 999    B+
# Name: math score, Length: 1000, dtype: category
# Categories (4, object): ['C' < 'B-' < 'B+' < 'A']

# %%
bin_edges
# Out:
# array([  0.,  53.,  66.,  79., 100.])

# %%
result_table = pd.DataFrame(zip(bin_edges , grades) ,columns= ['Limits ' , 'grades'])
result_table
# Out:
#    Limits  grades
# 0      0.0      C
# 1     53.0     B-
# 2     66.0     B+
# 3     79.0      A

# %%
####################### ANOTHER EXAMPLE ####################

# %%
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Cut the sepal lenth data into " Small" , "Medium " and "LArge"
df1["Sepal"] = pd.cut(df1.SepalLengthCm , bins = 3)
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species         Sepal
# 0       Iris-setosa  (4.296, 5.5]
# 1       Iris-setosa  (4.296, 5.5]
# 2       Iris-setosa  (4.296, 5.5]
# ...

# %%
# Cut the sepal lenth data into " Small" , "Medium " and "LArge"
df1["Sepal"] = pd.cut(df1.SepalLengthCm , bins = 3 , labels= ["Small" , "Medium" , "Large"])
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species   Sepal
# 0       Iris-setosa   Small
# 1       Iris-setosa   Small
# 2       Iris-setosa   Small
# 3       Iris-setosa   Small
# ...

# %%
df5=df1.groupby("Sepal").mean()

# %%
df5
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Sepal
# Small    37.067797       5.018644      3.191525       1.944068      0.438983
# Medium   96.549296       6.136620      2.923944       4.669014      1.604225
# Large   114.150000       7.235000      3.110000       5.880000      2.000000

# %%
df6=df1.groupby("Sepal").median()
df6
# Out:
#          Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Sepal
# Small    33            5.0          3.20           1.50           0.2
# Medium   96            6.1          2.90           4.80           1.5
# Large   120            7.2          3.05           5.95           2.1

# %%
df5=df1.groupby("Sepal").mean().SepalLengthCm
df5
# Out:
# Sepal
# Small     5.018644
# Medium    6.136620
# Large     7.235000
# Name: SepalLengthCm, dtype: float64

# %%
df5=df1.groupby("Sepal").mean().SepalLengthCm.plot()

# %%
df5=df1.groupby("Sepal").mean().SepalLengthCm.plot(kind = "bar")

# %%
df1.groupby("Sepal").mean().SepalLengthCm.plot(kind = "box")
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species   Sepal
# 0       Iris-setosa   Small
# 1       Iris-setosa   Small
# 2       Iris-setosa   Small
# 3       Iris-setosa   Small
# ...

# %%
df1.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from matplotlib import colors
import numpy as np
color=list(colors.ColorConverter.colors.keys())[0:3]
x=0
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
for i in df1.Species.unique():
    df1[df1.Species==i].plot(kind="scatter",x="Sepal",y="SepalLengthCm",label=i,c=color[x],ax=ax)
    x=x+1
    plt.figure()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
for i in df1.Species.unique():
    df1[df1.Species == i].plot(kind = "scatter" , x = "Sepal" , y = "SepalLengthCm" , label =i, color = 'red' ,ax =ax)
    x=x+1
    plt.figure()

# %%
from matplotlib import colors
import numpy as np
color=list(colors.ColorConverter.colors.keys())[0:3]
x=0
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
for i in df1.Species.unique():
    df1[df1.Species == i].plot(kind = "scatter" , x = "Sepal" , y = "SepalLengthCm" , label =i, c =color[x],ax =ax)
    x=x+1
    plt.figure()

# %%
################################ PLOTTING FUNCTION ###################

# %%
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species   Sepal
# 0       Iris-setosa   Small
# 1       Iris-setosa   Small
# 2       Iris-setosa   Small
# 3       Iris-setosa   Small
# ...

# %%
#df1 = df1.drop(columns="Sepal")
pd.plotting.parallel_coordinates(df1,"Species", color = ("red","blue","green"))
# Out:
# <AxesSubplot:>

# %%
pd.plotting.scatter_matrix(df1)
# Out:
# array([[<AxesSubplot:xlabel='Id', ylabel='Id'>,
#         <AxesSubplot:xlabel='SepalLengthCm', ylabel='Id'>,
#         <AxesSubplot:xlabel='SepalWidthCm', ylabel='Id'>,
#         <AxesSubplot:xlabel='PetalLengthCm', ylabel='Id'>,
#         <AxesSubplot:xlabel='PetalWidthCm', ylabel='Id'>],
#        [<AxesSubplot:xlabel='Id', ylabel='SepalLengthCm'>,
#         <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalLengthCm'>,
#         <AxesSubplot:xlabel='SepalWidthCm', ylabel='SepalLengthCm'>,
#         <AxesSubplot:xlabel='PetalLengthCm', ylabel='SepalLengthCm'>,
#         <AxesSubplot:xlabel='PetalWidthCm', ylabel='SepalLengthCm'>],
#        [<AxesSubplot:xlabel='Id', ylabel='SepalWidthCm'>,
#         <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>,
#         <AxesSubplot:xlabel='SepalWidthCm', ylabel='SepalWidthCm'>,
#         <AxesSubplot:xlabel='PetalLengthCm', ylabel='SepalWidthCm'>,
#         <AxesSubplot:xlabel='PetalWidthCm', ylabel='SepalWidthCm'>],
# ...
